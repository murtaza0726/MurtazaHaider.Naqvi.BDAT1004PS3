# %% [markdown]
# # Question: 1

# %%
import requests
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime

# %%
users = pd.read_csv('/Users/faizanhaidernaqvi/Downloads/occupations.csv')

# %%
users
# Out:
#      user_id  age gender     occupation zip_code
# 0          1   24      M     technician    85711
# 1          2   53      F          other    94043
# 2          3   23      M         writer    32067
# 3          4   24      M     technician    43537
# 4          5   33      F          other    15213
# ..       ...  ...    ...            ...      ...
# 938      939   26      F        student    33319
# 939      940   32      M  administrator     2215
# 940      941   20      M        student    97229
# 941      942   48      F      librarian    78209
# 942      943   22      M        student    77841
#
# [943 rows x 5 columns]

# %%
users.groupby('occupation').mean(['age'])
# Out:
#                   user_id        age
# occupation
# administrator  430.949367  38.746835
# artist         451.892857  31.392857
# doctor         533.714286  43.571429
# educator       466.905263  42.010526
# engineer       456.328358  36.388060
# entertainment  398.000000  29.222222
# executive      422.312500  38.718750
# healthcare     501.437500  41.562500
# homemaker      443.000000  32.571429
# lawyer         359.083333  36.750000
# librarian      486.588235  40.000000
# marketing      437.807692  37.615385
# none           368.666667  26.555556
# other          542.733333  34.523810
# programmer     435.530303  33.121212
# retired        515.714286  63.071429
# salesman       494.916667  35.666667
# scientist      465.129032  35.548387
# student        484.954082  22.081633
# technician     497.629630  33.148148
# writer         495.711111  36.311111

# %%
users['is_male'] = users.gender.apply(lambda x: True if x == 'M' else False)
percent = (users.groupby('occupation').is_male.sum() / users.groupby('occupation').gender.count())*100
percent.sort_values(ascending = False)
# Out:
# occupation
# doctor           100.000000
# engineer          97.014925
# technician        96.296296
# retired           92.857143
# programmer        90.909091
# executive         90.625000
# scientist         90.322581
# entertainment     88.888889
# lawyer            83.333333
# salesman          75.000000
# educator          72.631579
# student           69.387755
# other             65.714286
# marketing         61.538462
# writer            57.777778
# none              55.555556
# administrator     54.430380
# artist            53.571429
# librarian         43.137255
# healthcare        31.250000
# homemaker         14.285714
# dtype: float64

# %%
# min max
users.groupby('occupation').agg({'age': ['min', 'max']})
# Out:
#               age
#               min max
# occupation
# administrator  21  70
# artist         19  48
# doctor         28  64
# educator       23  63
# engineer       22  70
# entertainment  15  50
# executive      22  69
# healthcare     22  62
# homemaker      20  50
# lawyer         21  53
# librarian      23  69
# marketing      24  55
# none           11  55
# other          13  64
# programmer     20  63
# retired        51  73
# salesman       18  66
# scientist      23  55
# student         7  42
# technician     21  55
# writer         18  60

# %%
users.groupby(['occupation','gender']).agg({'age': ['mean']})
# Out:
#                             age
#                            mean
# occupation    gender
# administrator F       40.638889
#               M       37.162791
# artist        F       30.307692
#               M       32.333333
# doctor        M       43.571429
# educator      F       39.115385
#               M       43.101449
# engineer      F       29.500000
#               M       36.600000
# entertainment F       31.000000
#               M       29.000000
# executive     F       44.000000
#               M       38.172414
# healthcare    F       39.818182
#               M       45.400000
# homemaker     F       34.166667
#               M       23.000000
# lawyer        F       39.500000
#               M       36.200000
# librarian     F       40.000000
#               M       40.000000
# marketing     F       37.200000
#               M       37.875000
# none          F       36.500000
#               M       18.600000
# other         F       35.472222
# ...

# %% [markdown]
# # Question:2

# %%
#imported the libraries in the first cell

# %%
euro12 = pd.read_csv('/Users/faizanhaidernaqvi/Downloads/Question2.csv')

# %%
euro12
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 0               Croatia      4               13                12
# 1        Czech Republic      4               13                18
# 2               Denmark      4               10                10
# 3               England      5               11                18
# 4                France      3               22                24
# 5               Germany     10               32                32
# 6                Greece      5                8                18
# 7                 Italy      6               34                45
# 8           Netherlands      2               12                36
# 9                Poland      2               15                23
# 10             Portugal      6               22                42
# 11  Republic of Ireland      1                7                12
# 12               Russia      5                9                31
# ...

# %%
print(euro12['Goals'])
# Out:
# 0      4
# 1      4
# 2      4
# 3      5
# 4      3
# 5     10
# 6      5
# 7      6
# 8      2
# 9      2
# 10     6
# 11     1
# 12     5
# 13    12
# 14     5
# 15     2
# Name: Goals, dtype: int64

# %%
count = 0
for i in euro12['Team']:
    count = count + 1

print(count)
# Out:
# 16

# %%
euro12.shape[1]
# Out:
# 35

# %%
discipline = euro12[['Team', 'Yellow Cards', 'Red Cards']]
discipline
# Out:
#                    Team  Yellow Cards  Red Cards
# 0               Croatia             9          0
# 1        Czech Republic             7          0
# 2               Denmark             4          0
# 3               England             5          0
# 4                France             6          0
# 5               Germany             4          0
# 6                Greece             9          1
# 7                 Italy            16          0
# 8           Netherlands             5          0
# 9                Poland             7          1
# 10             Portugal            12          0
# 11  Republic of Ireland             6          1
# 12               Russia             6          0
# 13                Spain            11          0
# 14               Sweden             7          0
# 15              Ukraine             5          0

# %%
discipline.sort_values(['Red Cards', 'Yellow Cards'], ascending = False)
# Out:
#                    Team  Yellow Cards  Red Cards
# 6                Greece             9          1
# 9                Poland             7          1
# 11  Republic of Ireland             6          1
# 7                 Italy            16          0
# 10             Portugal            12          0
# 13                Spain            11          0
# 0               Croatia             9          0
# 1        Czech Republic             7          0
# 14               Sweden             7          0
# 4                France             6          0
# 12               Russia             6          0
# 3               England             5          0
# 8           Netherlands             5          0
# 15              Ukraine             5          0
# 2               Denmark             4          0
# 5               Germany             4          0

# %%
discipline['Yellow Cards'].mean()
# Out:
# 7.4375

# %%
euro12[euro12.Goals > 6]['Team']
# Out:
# 5     Germany
# 13      Spain
# Name: Team, dtype: object

# %%
euro12[euro12.Team.str.startswith('G')]['Team']
# Out:
# 5    Germany
# 6     Greece
# Name: Team, dtype: object

# %%
euro12.iloc[: , 0:7]
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 0               Croatia      4               13                12
# 1        Czech Republic      4               13                18
# 2               Denmark      4               10                10
# 3               England      5               11                18
# 4                France      3               22                24
# 5               Germany     10               32                32
# 6                Greece      5                8                18
# 7                 Italy      6               34                45
# 8           Netherlands      2               12                36
# 9                Poland      2               15                23
# 10             Portugal      6               22                42
# 11  Republic of Ireland      1                7                12
# 12               Russia      5                9                31
# ...

# %%
euro12.iloc[: , :-3]
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 0               Croatia      4               13                12
# 1        Czech Republic      4               13                18
# 2               Denmark      4               10                10
# 3               England      5               11                18
# 4                France      3               22                24
# 5               Germany     10               32                32
# 6                Greece      5                8                18
# 7                 Italy      6               34                45
# 8           Netherlands      2               12                36
# 9                Poland      2               15                23
# 10             Portugal      6               22                42
# 11  Republic of Ireland      1                7                12
# 12               Russia      5                9                31
# ...

# %%
euro12.loc[euro12['Team'].isin(['England', 'Italy', 'Russia'])][['Team','Shooting Accuracy']]
# Out:
#        Team Shooting Accuracy
# 3   England             50.0%
# 7     Italy             43.0%
# 12   Russia             22.5%

# %% [markdown]
# # Question: 3

# %%
#imported the libraries in the first cell

# %%
df1 = pd.Series(np.random.randint(1,5,size=100))
df2 = pd.Series(np.random.randint(1,4,size=100))
df3 = pd.Series(np.random.randint(10000,30001,size=100))
print(df1,df2,df3)
# Out:
# 0     1
# 1     1
# 2     4
# 3     3
# 4     2
#      ..
# 95    1
# 96    4
# 97    2
# 98    1
# 99    2
# Length: 100, dtype: int64 0     1
# 1     2
# 2     3
# 3     1
# 4     2
#      ..
# 95    1
# 96    3
# 97    1
# 98    1
# 99    2
# Length: 100, dtype: int64 0     29118
# 1     23572
# 2     19830
# 3     13129
# 4     20721
#       ...
# 95    22113
# 96    28571
# 97    27933
# 98    14919
# 99    14232
# Length: 100, dtype: int64

# %%
dataf = pd.concat([df1, df2, df3], axis=1)
dataf.head()
# Out:
#    0  1      2
# 0  1  1  29118
# 1  1  2  23572
# 2  4  3  19830
# 3  3  1  13129
# 4  2  2  20721

# %%
dataf.rename(columns = {0: 'bedrs', 1: 'bathrs', 2: 'price_sqr_meter'}, inplace=True)
dataf.head()
# Out:
#    bedrs  bathrs  price_sqr_meter
# 0      1       1            29118
# 1      1       2            23572
# 2      4       3            19830
# 3      3       1            13129
# 4      2       2            20721

# %%
bigcolumn = pd.concat([df1, df1, df1], axis=0)

# %%
bigcolumn = bigcolumn.to_frame()
print(type(bigcolumn))

bigcolumn
# Out:
# <class 'pandas.core.frame.DataFrame'>
#     0
# 0   1
# 1   1
# 2   4
# 3   3
# 4   2
# .. ..
# 95  1
# 96  4
# 97  2
# 98  1
# 99  2
#
# [300 rows x 1 columns]

# %%
len(bigcolumn)
# Out:
# 300

# %%
bigcolumn.reset_index()
bigcolumn
# Out:
#     0
# 0   1
# 1   1
# 2   4
# 3   3
# 4   2
# .. ..
# 95  1
# 96  4
# 97  2
# 98  1
# 99  2
#
# [300 rows x 1 columns]

# %% [markdown]
# # Question: 4

# %%
#imported the libraries in the first cell

# %%
data = pd.read_csv('/Users/faizanhaidernaqvi/Downloads/Question4.csv', sep = "\s+", parse_dates = [[0,1,2]]) 
data.head()
# Out:
#     Yr_Mo_Dy    RPT    VAL    ROS    KIL    SHA   BIR    DUB    CLA    MUL  \
# 0 2061-01-01  15.04  14.96  13.17   9.29    NaN  9.87  13.67  10.25  10.83
# 1 2061-01-02  14.71    NaN  10.83   6.50  12.62  7.67  11.50  10.04   9.79
# 2 2061-01-03  18.50  16.88  12.33  10.13  11.17  6.17  11.25    NaN   8.50
# 3 2061-01-04  10.58   6.63  11.75   4.58   4.54  2.88   8.63   1.79   5.83
# 4 2061-01-05  13.33  13.25  11.42   6.17  10.71  8.21  11.92   6.54  10.92
#
#      CLO    BEL    MAL
# 0  12.58  18.50  15.04
# 1   9.67  17.54  13.83
# 2   7.67  12.75  12.71
# 3   5.88   5.46  10.88
# 4  10.34  12.92  11.83

# %%
def fix_century(x):
  year = x.year - 100 if x.year > 1989 else x.year
  return datetime.date(year, x.month, x.day)
data['Yr_Mo_Dy'] = data['Yr_Mo_Dy'].apply(fix_century)
data.head()
# Out:
#      Yr_Mo_Dy    RPT    VAL    ROS    KIL    SHA   BIR    DUB    CLA    MUL  \
# 0  1961-01-01  15.04  14.96  13.17   9.29    NaN  9.87  13.67  10.25  10.83
# 1  1961-01-02  14.71    NaN  10.83   6.50  12.62  7.67  11.50  10.04   9.79
# 2  1961-01-03  18.50  16.88  12.33  10.13  11.17  6.17  11.25    NaN   8.50
# 3  1961-01-04  10.58   6.63  11.75   4.58   4.54  2.88   8.63   1.79   5.83
# 4  1961-01-05  13.33  13.25  11.42   6.17  10.71  8.21  11.92   6.54  10.92
#
#      CLO    BEL    MAL
# 0  12.58  18.50  15.04
# 1   9.67  17.54  13.83
# 2   7.67  12.75  12.71
# 3   5.88   5.46  10.88
# 4  10.34  12.92  11.83

# %%
data["Yr_Mo_Dy"] = pd.to_datetime(data["Yr_Mo_Dy"])
data = data.set_index('Yr_Mo_Dy')

# %%
data.head()
# Out:
#               RPT    VAL    ROS    KIL    SHA   BIR    DUB    CLA    MUL  \
# Yr_Mo_Dy
# 1961-01-01  15.04  14.96  13.17   9.29    NaN  9.87  13.67  10.25  10.83
# 1961-01-02  14.71    NaN  10.83   6.50  12.62  7.67  11.50  10.04   9.79
# 1961-01-03  18.50  16.88  12.33  10.13  11.17  6.17  11.25    NaN   8.50
# 1961-01-04  10.58   6.63  11.75   4.58   4.54  2.88   8.63   1.79   5.83
# 1961-01-05  13.33  13.25  11.42   6.17  10.71  8.21  11.92   6.54  10.92
#
#               CLO    BEL    MAL
# Yr_Mo_Dy
# 1961-01-01  12.58  18.50  15.04
# 1961-01-02   9.67  17.54  13.83
# 1961-01-03   7.67  12.75  12.71
# 1961-01-04   5.88   5.46  10.88
# 1961-01-05  10.34  12.92  11.83

# %%
data.isnull().sum()
# Out:
# RPT    6
# VAL    3
# ROS    2
# KIL    5
# SHA    2
# BIR    0
# DUB    3
# CLA    2
# MUL    3
# CLO    1
# BEL    0
# MAL    4
# dtype: int64

# %%
data.notnull().sum()
# Out:
# RPT    6568
# VAL    6571
# ROS    6572
# KIL    6569
# SHA    6572
# BIR    6574
# DUB    6571
# CLA    6572
# MUL    6571
# CLO    6573
# BEL    6574
# MAL    6570
# dtype: int64

# %%
fdata = data.sum().sum() / data.notna().sum().sum()
print(round(fdata))
# Out:
# 10

# %%
data.describe(percentiles=[])
# Out:
#                RPT          VAL          ROS          KIL          SHA  \
# count  6568.000000  6571.000000  6572.000000  6569.000000  6572.000000
# mean     12.362987    10.644314    11.660526     6.306468    10.455834
# std       5.618413     5.267356     5.008450     3.605811     4.936125
# min       0.670000     0.210000     1.500000     0.000000     0.130000
# 50%      11.710000    10.170000    10.920000     5.750000     9.960000
# max      35.800000    33.370000    33.840000    28.460000    37.540000
#
#                BIR          DUB          CLA          MUL          CLO  \
# count  6574.000000  6571.000000  6572.000000  6571.000000  6573.000000
# mean      7.092254     9.797343     8.495053     8.493590     8.707332
# std       3.968683     4.977555     4.499449     4.166872     4.503954
# min       0.000000     0.000000     0.000000     0.000000     0.040000
# 50%       6.830000     9.210000     8.080000     8.170000     8.290000
# ...

# %%
day_stats = pd.DataFrame()

day_stats['min'] = data.min(axis = 1)
day_stats['max'] = data.max(axis = 1)
day_stats['mean'] = data.mean(axis = 1) 
day_stats['std'] = data.std(axis = 1) 

day_stats.head()
# Out:
#              min    max       mean       std
# Yr_Mo_Dy
# 1961-01-01  9.29  18.50  13.018182  2.808875
# 1961-01-02  6.50  17.54  11.336364  3.188994
# 1961-01-03  6.17  18.50  11.641818  3.681912
# 1961-01-04  1.79  11.75   6.619167  3.198126
# 1961-01-05  6.17  13.33  10.630000  2.445356

# %%
data.loc[data.index.month == 1].mean()
# Out:
# RPT    14.847325
# VAL    12.914560
# ROS    13.299624
# KIL     7.199498
# SHA    11.667734
# BIR     8.054839
# DUB    11.819355
# CLA     9.512047
# MUL     9.543208
# CLO    10.053566
# BEL    14.550520
# MAL    18.028763
# dtype: float64

# %%
data.groupby(data.index.to_period('A')).mean()
# Out:
#                 RPT        VAL        ROS       KIL        SHA       BIR  \
# Yr_Mo_Dy
# 1961      12.299583  10.351796  11.362369  6.958227  10.881763  7.729726
# 1962      12.246923  10.110438  11.732712  6.960440  10.657918  7.393068
# 1963      12.813452  10.836986  12.541151  7.330055  11.724110  8.434712
# 1964      12.363661  10.920164  12.104372  6.787787  11.454481  7.570874
# 1965      12.451370  11.075534  11.848767  6.858466  11.024795  7.478110
# 1966      13.461973  11.557205  12.020630  7.345726  11.805041  7.793671
# 1967      12.737151  10.990986  11.739397  7.143425  11.630740  7.368164
# 1968      11.835628  10.468197  11.409754  6.477678  10.760765  6.067322
# 1969      11.166356   9.723699  10.902000  5.767973   9.873918  6.189973
# 1970      12.600329  10.726932  11.730247  6.217178  10.567370  7.609452
# 1971      11.273123   9.095178  11.088329  5.241507   9.440329  6.097151
# 1972      12.463962  10.561311  12.058333  5.929699   9.430410  6.358825
# ...

# %%
data.groupby(data.index.to_period('M')).mean()
# Out:
#                 RPT        VAL        ROS       KIL        SHA        BIR  \
# Yr_Mo_Dy
# 1961-01   14.841333  11.988333  13.431613  7.736774  11.072759   8.588065
# 1961-02   16.269286  14.975357  14.441481  9.230741  13.852143  10.937500
# 1961-03   10.890000  11.296452  10.752903  7.284000  10.509355   8.866774
# 1961-04   10.722667   9.427667   9.998000  5.830667   8.435000   6.495000
# 1961-05    9.860968   8.850000  10.818065  5.905333   9.490323   6.574839
# ...             ...        ...        ...       ...        ...        ...
# 1978-08    9.645161   8.259355   9.032258  4.502903   7.368065   5.935161
# 1978-09   10.913667  10.895000  10.635000  5.725000  10.372000   9.278333
# 1978-10    9.897742   8.670968   9.295806  4.721290   8.525161   6.774194
# 1978-11   16.151667  14.802667  13.508000  7.317333  11.475000   8.743000
# 1978-12   16.175484  13.748065  15.635161  7.094839  11.398710   9.241613
#
# ...

# %%
data.groupby(data.index.to_period('W')).mean()
# Out:
#                              RPT        VAL        ROS        KIL        SHA  \
# Yr_Mo_Dy
# 1960-12-26/1961-01-01  15.040000  14.960000  13.170000   9.290000        NaN
# 1961-01-02/1961-01-08  13.541429  11.486667  10.487143   6.417143   9.474286
# 1961-01-09/1961-01-15  12.468571   8.967143  11.958571   4.630000   7.351429
# 1961-01-16/1961-01-22  13.204286   9.862857  12.982857   6.328571   8.966667
# 1961-01-23/1961-01-29  19.880000  16.141429  18.225714  12.720000  17.432857
# ...                          ...        ...        ...        ...        ...
# 1978-11-27/1978-12-03  14.934286  11.232857  13.941429   5.565714  10.215714
# 1978-12-04/1978-12-10  20.740000  19.190000  17.034286   9.777143  15.287143
# 1978-12-11/1978-12-17  16.758571  14.692857  14.987143   6.917143  11.397143
# 1978-12-18/1978-12-24  11.155714   8.008571  13.172857   4.004286   7.825714
# 1978-12-25/1978-12-31  14.951429  11.801429  16.035714   6.507143   9.660000
#
# ...

# %%
weekly = data.resample('W').agg(['min','max','mean','std'])

# %%
weekly.loc[weekly.index[1:53], "RPT":"MAL"] .head(10)
# Out:
#               RPT                                VAL                    \
#               min    max       mean       std    min    max       mean
# Yr_Mo_Dy
# 1961-01-08  10.58  18.50  13.541429  2.631321   6.63  16.88  11.486667
# 1961-01-15   9.04  19.75  12.468571  3.555392   3.54  12.08   8.967143
# 1961-01-22   4.92  19.83  13.204286  5.337402   3.42  14.37   9.862857
# 1961-01-29  13.62  25.04  19.880000  4.619061   9.96  23.91  16.141429
# 1961-02-05  10.58  24.21  16.827143  5.251408   9.46  24.21  15.460000
# 1961-02-12  16.00  24.54  19.684286  3.587677  11.54  21.42  16.417143
# 1961-02-19   6.04  22.50  15.130000  5.064609  11.63  20.17  15.091429
# 1961-02-26   7.79  25.80  15.221429  7.020716   7.08  21.50  13.625714
# 1961-03-05  10.96  13.33  12.101429  0.997721   8.83  17.00  12.951429
# 1961-03-12   4.88  14.79   9.376667  3.732263   8.08  16.96  11.578571
#
#                         ROS         ...        CLO              BEL         \
# ...

# %% [markdown]
# # Question:5

# %%
#imported the libraries in the first cell

# %%
chipo = pd.read_csv('/Users/faizanhaidernaqvi/Downloads/Question5.tsv', sep = '\t')

# %%
chipo.head(10)
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
# 5         3         1                           Chicken Bowl
# 6         3         1                          Side of Chips
# 7         4         1                          Steak Burrito
# 8         4         1                       Steak Soft Tacos
# 9         5         1                          Steak Burrito
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# ...

# %%
chipo.shape[0]
# Out:
# 4622

# %%
chipo.shape[1]
# Out:
# 5

# %%
print(chipo.columns)
# Out:
# Index(['order_id', 'quantity', 'item_name', 'choice_description',
#        'item_price'],
#       dtype='object')

# %%
print(chipo.index)
# Out:
# RangeIndex(start=0, stop=4622, step=1)

# %%
mostOrdered = chipo.groupby('choice_description').sum()
mostOrdered = mostOrdered.sort_values('quantity', ascending=False)
mostOrdered.head(1)
# Out:
#                     order_id  quantity
# choice_description
# [Diet Coke]           123455       159

# %%
chipo.quantity.sum()
# Out:
# 4972

# %%
chipo.item_price.dtype
# Out:
# dtype('O')

# %%
itemType = lambda x: float(x[1:-1])
chipo.item_price = chipo.item_price.apply(itemType)

# %%
chipo.item_price.dtype
# Out:
# dtype('float64')

# %%
revenue = (chipo['quantity']* chipo['item_price']).sum()

print(np.round(revenue,2))
# Out:
# 39237.02

# %%
chipo.order_id.value_counts().count()
# Out:
# 1834

# %%
chipo['revenue'] = chipo['quantity'] * chipo['item_price']

# %%
chipo.groupby(by=['order_id']).sum().mean()['revenue']
# Out:
# 21.394231188658654

# %%
chipo.item_name.value_counts().count()
# Out:
# 50

# %% [markdown]
# # Question: 6

# %%
marriage = pd.read_csv('/Users/faizanhaidernaqvi/Downloads/us-marriages-divorces-1867-2014.csv')

# %%
plt.plot(marriage['Year'], marriage['Marriages']/marriage['Population'], label = "Marriages", color="red")
plt.plot(marriage['Year'], marriage['Divorces']/marriage['Population'], label = "Divorces", color="blue")
legands = plt.legend()
plt.xlabel("Years")
plt.ylabel("marriages & divorces per capita")
# Out:
# Text(0, 0.5, 'marriages & divorces per capita')

# %% [markdown]
# # Question: 7

# %%
usData = pd.read_csv('/Users/faizanhaidernaqvi/Downloads/us-marriages-divorces-1867-2014.csv')
usData = usData[usData['Year'].apply(lambda x: x in [1900, 1950, 2000])]

years = usData['Year'].values
marriagesCapita = usData['Marriages_per_1000'].values
divorcesCapita = usData['Divorces_per_1000'].values
plt.bar(x=(years - width/2), height=marriagesCapita, width=width, label='Marriage/Capita')
plt.bar(x=(years + width/2), height=divorcesCapita, width=width, label='Divorce/Capita')
plt.xlabel('Year')
plt.ylabel('Capita Count')
plt.legend()
plt.show()

# %% [markdown]
# # Question: 8

# %%
holly = pd.read_csv('/Users/faizanhaidernaqvi/Downloads/actor_kill_counts.csv')
actor = holly['Actor'].values
kill = holly['Count'].values

plt.barh(actor, kill, color="maroon")
plt.xlabel('Year')
plt.ylabel('Per Capita')
# Out:
# Text(0, 0.5, 'Per Capita')

# %% [markdown]
# # Question: 9

# %%
romanEmp = pd.read_csv('/Users/faizanhaidernaqvi/Downloads/roman-emperor-reigns.csv')
assassinatedEmp = romanEmp[romanEmp['Cause_of_Death'].apply(lambda x: 'assassinated' in x.lower())]
Assassination = len(assassinatedEmp)
otherDeaths = len(romanEmp) - Assassination
plt.pie([Assassination, otherDeaths], colors=['Orange', 'Grey'], startangle=90, autopct='%2.1f%%', labels=['Assassinated', 'Other'])
plt.show()

# %% [markdown]
# # Question: 10

# %%
arcade = pd.read_csv('/Users/faizanhaidernaqvi/Downloads/arcade-revenue-vs-cs-doctorates.csv')
arcRevenue = arcade['Total Arcade Revenue (billions)'].values
docAwarded = arcade['Computer Science Doctorates Awarded (US)'].values
plt.scatter(arcRevenue, docAwarded, color='grey')
plt.xlabel('Revinues Earned by Arcades')
plt.ylabel('Computer Science Awards')
plt.show()
